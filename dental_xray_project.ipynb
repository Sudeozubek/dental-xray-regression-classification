# %% [markdown]
# # Dental X-ray ML Project (Regression + Classification with CV)

# %% [markdown]
# Full code is provided in segments (dataset download, preprocessing, feature extraction, regression, classification, CV evaluation).
